# %% [markdown]
# # Images as numbers (A computer's perspective)

# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %%
cell_location = 'C:\\Users\\Keira\\Downloads\\textile\\example_data\\ogd_cells.tif'

# %%
cell_image = io.imread(cell_location)

# %%
plt.imshow(cell_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cell_image
# Out:
# array([[[ 17,  25,   0],
#         [134, 101,  22],
#         [  0,  65,  16],
#         ...,
#         [251,  16,  26],
#         [268,  11,  32],
#         [261,   0,  19]],
#
#        [[100, 122,   0],
#         [ 31, 136,  16],
#         [ 57,  74,  11],
#         ...,
#         [ 79,  14,   0],
#         [298,   8,  27],
#         [277,  11,  31]],
#
#        [[101,  29,   5],
#         [ 10,  84,   0],
#         [ 35, 111,  11],
#         ...,
#         [240,  22,   7],
#         [181,   0,   9],
#         [256,  15,  29]],
#
#        ...,
#
#        [[ 24,  22,  10],
#         [ 16, 140,   9],
#         [ 70,  78,   2],
#         ...,
#         [103,  11,   7],
#         [  3,   7,   2],
#         [ 33,   0,   4]],
#
#        [[ 17,  80,  10],
#         [  5,  59,   6],
#         [  0, 102,   3],
#         ...,
#         [ 15,   8,   8],
#         [ 31,  11,  14],
#         [137,  15,   0]],
#
#        [[ 62,  27,  18],
#         [ 38,  52,   1],
#         [ 13,  27,   0],
# ...

# %%
cell_image.shape
# Out:
# (512, 512, 3)

# %%
red_cell_image = cell_image[:, :, 0]
green_cell_image = cell_image[:, :, 1]
blue_cell_image = cell_image[:, :, 2]

# %%
plt.imshow(red_cell_image, cmap='Greys')

# %%
plt.imshow(green_cell_image)
